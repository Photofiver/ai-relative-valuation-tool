# %%
# !pip install pandas tabulate -q

# %%
import pandas as pd
from io import StringIO
import warnings
warnings.filterwarnings('ignore')

print('Wklej swoje dane 25 spółek i uruchom')

csv_data = '''Ticker,PE,PE_fwd,PEG,PB,PS,EV_EBITDA,ROE,RevGrowth
MMM,29.43,16.12,1.6,24.37,3.18,13.92,71.46,1.3
AOS,15.27,13.71,1.49,4.20,2.07,10.50,28.27,-1.9
ABT,24.48,14.41,1.3,2.92,3.37,15.30,12.33,7.8
ABBV,105.22,13.29,0.59,-57.26,6.07,14.86,nan,12.4
ACN,14.68,12.02,1.26,3.53,1.53,8.68,24.76,8.3
ADBE,14.26,9.28,0.69,8.69,4.05,10.37,58.77,12
AMD,156.36,36.07,1.12,11.82,20.35,101.46,8.06,37.8
AES,7.65,6.15,0.81,2.37,0.84,12.90,5.26,8.7
AFL,13.47,15.50,1.18,2.01,3.31,11.26,16.47,27.9
A,25.38,17.52,1.2,4.70,4.60,17.39,19.95,7
APD,30.50,20.32,2.34,4.12,5.17,21.78,12.35,8.8
ABNB,32.68,21.89,1.24,10.31,6.21,26.38,32.32,17.9
AKAM,49.74,20.53,1.74,4.37,5.02,22.97,9.17,5.8
ALB,nan,15.19,1.13,2.66,3.68,22.15,-1.82,32.7
ARE,nan,-54.97,3.24,0.52,2.88,13.18,-4.14,-11.5
ALGN,27.45,13.22,0.86,2.82,2.86,12.10,10.82,6.2
ALLE,17.82,13.67,2.01,5.33,2.70,12.99,34.18,9.7
LNT,23.25,20.07,2.56,2.57,4.32,16.61,11.31,5
ALL,4.79,8.26,2.6,1.89,0.82,4.03,45.22,3
GOOGL,29.23,26.50,1.51,9.69,10.98,28.57,38.88,21.8
GOOG,28.89,26.25,1.51,9.60,10.88,28.30,38.88,21.8
MO,15.43,12.60,1.69,-38.45,6.06,9.15,nan,5.3
AMZN,31.63,27.04,1.83,6.48,3.86,18.97,24.29,16.6
AMCR,30.95,8.95,0.53,1.52,0.80,10.29,8.74,77.4
AEE,20.02,19.17,2.6,2.27,3.60,13.65,11.75,3.7'''

df = pd.read_csv(StringIO(csv_data))

print('='*80)
print('ANALIZA - TYLKO TWOJE DANE I KRYTERIA')
print('='*80)

# 1. Twarde wskaźniki
print('1. Twarde wskaźniki:')
print('P/E < 15 (ideally <10):', 'spełnia kilka spółek (AES, AFL, ACN, ADBE, ALL). Większość ma wyższe.' if (df['PE'] < 15).any() else 'nie spełnia')
print('P/B < 1.5 (≤ 2 dla rosnących):', 'spełnia bardzo mało (głównie ARE, AMCR).' if (df['PB'] < 1.5).any() else 'nie spełnia')
print('P/S < 1 (ideally <0.5):', 'spełnia bardzo mało spółek.' if (df['PS'] < 1).any() else 'nie spełnia')
print('EV/EBITDA < 10 (preferowane <7):', 'spełnia kilka (ALL, ACN, MO).' if (df['EV_EBITDA'] < 10).any() else 'nie spełnia')
print('ROE > 15% (najlepiej >20%):', 'spełnia sporo (MMM, ADBE, GOOGL/GOOG, ALL, ABNB, ALLE itd.).' if (df['ROE'] > 15).any() else 'nie spełnia')
print('Revenue Growth > 10%:', 'spełnia ok. 8-9 spółek (ADBE, AMD, AFL, ABNB, GOOGL/GOOG, AMZN, AMCR itd.).' if (df['RevGrowth'] > 10).any() else 'nie spełnia')
print('Adjusted P/S, D/E, FCF, Dividend Yield, Current Ratio, EPS Growth, Operating Margin, Gross Margin, Share Buybacks: brak danych')

# 2. Częściowo twarde
print('\n2. Częściowo twarde:')
print('CAPE < 20: brak danych')
print('Intrinsic Value + marża 20-30%: brak danych')

# 3. Jakościowe
print('\n3. Jakościowe:')
print('Earnings Retention Ratio, Economic Moat, Green Spike Flow, Przewaga konkurencyjna, Opis trendu technicznego: brak danych')

# Podsumowanie
print('\n' + '='*80)
print('PODSUMOWANIE')
print('='*80)
print('spełnione: kilka spółek na P/E, ROE i RevGrowth')
print('niespełnione: większość na P/B i P/S')
print('brak danych: bardzo dużo (D/E, FCF, Dividend Yield, marże, CAPE, Intrinsic Value, moat itd.)')
print('wniosek: mieszana - kilka spółek wygląda interesująco na dostępnych wskaźnikach, ale przy dużej liczbie brakujących danych nie da się wydać jednoznacznego werdyktu dla całej partii.')
